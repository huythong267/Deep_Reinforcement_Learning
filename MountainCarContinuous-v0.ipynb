# %%
# %load_ext autoreload
# %autoreload 2

from codes import trainer

# %% [markdown]
# # Double Deterministic Policy Gradient (DDPG)

# %%
kwargs = {
    'lr_actor': 0.001,
    'lr_critic': 0.001,
    'tau_actor': 0.01,
    'tau_critic': 0.01,
    'learn_every': 2,
    'sigma_noise': 0.15,
}
trainer.train(env_name='MountainCarContinuous-v0', algo_name='ddpg', solved_reward=85, 
              print_every=2, render_every=10, **kwargs)
# Out:
# Environment: MountainCarContinuous-v0 	 State_dim =  2 	 Action_dim =  1
# DDPG agent
# output_scale:  1.0
# learning_rate actor = 0.001, critic = 0.001
# weight_transfer tau actor = 0.01, critic = 0.01
# learn_every:  2
#
# sigma_noise:  0.15
# Examples of OUAactionNoise:
# [Episode    2] average_length:  666 	Rewards:  -30
# [Episode    4] average_length:  682 	Rewards:    8
# [Episode    6] average_length:  616 	Rewards:   29
# [Episode    8] average_length:  576 	Rewards:   40
# [Episode   10] average_length:  616 	Rewards:   36
# [Episode   12] average_length:  567 	Rewards:   43
# [Episode   14] average_length:  588 	Rewards:   40
# [Episode   16] average_length:  612 	Rewards:   38
# [Episode   18] average_length:  592 	Rewards:   42
# [Episode   20] average_length:  551 	Rewards:   47
# [Episode   22] average_length:  557 	Rewards:   49
# [Episode   24] average_length:  541 	Rewards:   52
# [Episode   26] average_length:  558 	Rewards:   49
# ...
