# %%
# %load_ext autoreload
# %autoreload 2

from codes import trainer

# %% [markdown]
# # DQN

# %%
kwargs = {
    'lr_critic': 0.001,
    'tau_critic': 0.01,
    'learn_every': 2,
    'eps_decay':0.99,
}
trainer.train(env_name='CartPole-v0', algo_name='dqn', solved_reward=195, **kwargs)
# Out:
# Environment: CartPole-v0 	 State_dim =  4 	 Action_dim =  2
# DQN agent with decay
# eps_decay :  0.99
# learning_rate:  0.001
# [Episode   20] average_length:   19 	Rewards:   19
# [Episode   40] average_length:   16 	Rewards:   16
# [Episode   60] average_length:   16 	Rewards:   16
# [Episode   80] average_length:   41 	Rewards:   41
# [Episode  100] average_length:  113 	Rewards:  113
# [Episode  120] average_length:  178 	Rewards:  178
# ########## Solved! ##########
# [Episode  130] average_length:  195 	Rewards:  195

# %%
kwargs = {
    'lr': 0.001,
    'tau': 0.01,
    'learn_every': 2,
    'eps_decay':0.98,
}
trainer.train(env_name='CartPole-v0', algo_name='dqn', solved_reward=195, **kwargs)
# Out:
# Environment: CartPole-v0 	 State_dim =  4 	 Action_dim =  2
# DQN agent with decay
# learning_rate:  0.001
# weight_transfer tau:  0.01
# learn_every:  2
# eps_decay :  0.98
#
# [Episode   20] average_length:   20 	Rewards:   20
# [Episode   40] average_length:   17 	Rewards:   17
# [Episode   60] average_length:   15 	Rewards:   15
# [Episode   80] average_length:   26 	Rewards:   26
# [Episode  100] average_length:   87 	Rewards:   87
# [Episode  120] average_length:  157 	Rewards:  157
# [Episode  140] average_length:  190 	Rewards:  190
# ########## Solved! ##########
# [Episode  157] average_length:  195 	Rewards:  195

# %% [markdown]
# # PPO

# %%
kwargs = {
    'lr_actor': 0.002, 
    'lr_critic': 0.005,
    'ppo_update_timestep': 300,
    'ppo_epsilon': 0.15,
    'ppo_epochs': 5,
}
trainer.train(env_name='CartPole-v0', algo_name='ppo', solved_reward=195, **kwargs)
# Out:
# Environment: CartPole-v0 	 State_dim =  4 	 Action_dim =  2
# PPO agent
# learning_rate actor = 0.002, critic = 0.005
# PPO ppo_epsilon 0.15
# PPO update timestep:  300
# PPO ppo_epochs 5
#
# [Episode   20] average_length:   19 	Rewards:   19
# [Episode   40] average_length:   20 	Rewards:   20
# [Episode   60] average_length:   24 	Rewards:   24
# [Episode   80] average_length:   48 	Rewards:   48
# [Episode  100] average_length:  104 	Rewards:  104
# [Episode  120] average_length:  168 	Rewards:  168
# [Episode  140] average_length:  181 	Rewards:  181
# [Episode  160] average_length:  185 	Rewards:  185
# [Episode  180] average_length:  192 	Rewards:  192
# ########## Solved! ##########
# [Episode  189] average_length:  195 	Rewards:  195

# %%
kwargs = {
    'lr_actor': 0.002, 
    'lr_critic': 0.005,
    'ppo_update_timestep': 200,
    'ppo_epsilon': 0.15,
    'ppo_epochs': 5,
}
trainer.train(env_name='CartPole-v0', algo_name='ppo', solved_reward=195, **kwargs)
# Out:
# Environment: CartPole-v0 	 State_dim =  4 	 Action_dim =  2
# PPO agent
# learning_rate actor = 0.002, critic = 0.005
# PPO ppo_epsilon 0.15
# PPO update timestep:  200
# PPO ppo_epochs 5
#
# [Episode   20] average_length:   19 	Rewards:   19
# [Episode   40] average_length:   21 	Rewards:   21
# [Episode   60] average_length:   35 	Rewards:   35
# [Episode   80] average_length:   82 	Rewards:   82
# [Episode  100] average_length:  135 	Rewards:  135
# [Episode  120] average_length:  178 	Rewards:  178
# [Episode  140] average_length:  180 	Rewards:  180
# [Episode  160] average_length:  191 	Rewards:  191
# ########## Solved! ##########
# [Episode  165] average_length:  195 	Rewards:  195

# %% [markdown]
# # REINFORCE

# %%
kwargs = {
    'lr_actor': 0.01, 
    'reinforce_update_timestep': 250,
}
trainer.train(env_name='CartPole-v0', algo_name='reinforce', solved_reward=195, **kwargs)
# Out:
# Environment: CartPole-v0 	 State_dim =  4 	 Action_dim =  2
# REINFORCE agent
# learning_rate actor = 0.01
# REINFORCE update timestep:  250
#
# [Episode   20] average_length:   16 	Rewards:   16
# [Episode   40] average_length:   19 	Rewards:   19
# [Episode   60] average_length:   22 	Rewards:   22
# [Episode   80] average_length:   28 	Rewards:   28
# [Episode  100] average_length:   54 	Rewards:   54
# [Episode  120] average_length:  114 	Rewards:  114
# [Episode  140] average_length:  145 	Rewards:  145
# [Episode  160] average_length:  168 	Rewards:  168
# [Episode  180] average_length:  179 	Rewards:  179
# ########## Solved! ##########
# [Episode  189] average_length:  195 	Rewards:  195

# %%
kwargs = {
    'lr_actor': 0.01, 
    'reinforce_update_timestep': 150,
}
trainer.train(env_name='CartPole-v0', algo_name='reinforce', solved_reward=195, **kwargs)
# Out:
# Environment: CartPole-v0 	 State_dim =  4 	 Action_dim =  2
# REINFORCE agent
# learning_rate actor = 0.01
# REINFORCE update timestep:  150
#
# [Episode   20] average_length:   22 	Rewards:   22
# [Episode   40] average_length:   27 	Rewards:   27
# [Episode   60] average_length:   35 	Rewards:   35
# [Episode   80] average_length:   72 	Rewards:   72
# [Episode  100] average_length:   93 	Rewards:   93
# [Episode  120] average_length:  130 	Rewards:  130
# [Episode  140] average_length:  158 	Rewards:  158
# [Episode  160] average_length:  163 	Rewards:  163
# [Episode  180] average_length:  130 	Rewards:  130
# [Episode  200] average_length:  115 	Rewards:  115
# [Episode  220] average_length:  138 	Rewards:  138
# [Episode  240] average_length:  134 	Rewards:  134
# [Episode  260] average_length:  111 	Rewards:  111
# [Episode  280] average_length:  123 	Rewards:  123
# [Episode  300] average_length:  177 	Rewards:  177
# ########## Solved! ##########
# ...
