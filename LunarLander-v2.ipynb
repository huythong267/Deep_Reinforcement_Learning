# %%
# %load_ext autoreload
# %autoreload 2

from codes import trainer

# %% [markdown]
# # Deep Q-Network (DQN)

# %%
kwargs = {
    'lr_critic': 0.0005,
    'tau_critic': 0.001,
    'learn_every': 4,
    'eps_decay':0.995,
}
trainer.train(env_name='LunarLander-v2', algo_name='dqn', solved_reward=200, **kwargs)
# Out:
# Environment: LunarLander-v2 	 State_dim =  8 	 Action_dim =  4
# DQN agent with decay
# learning_rate:  0.0005
# weight_transfer tau:  0.001
# learn_every:  4
# eps_decay :  0.995
#
# [Episode   20] average_length:  112 	Rewards: -172
# [Episode   40] average_length:  131 	Rewards: -207
# [Episode   60] average_length:  167 	Rewards: -223
# [Episode   80] average_length:  209 	Rewards: -222
# [Episode  100] average_length:  320 	Rewards: -216
# [Episode  120] average_length:  419 	Rewards: -177
# [Episode  140] average_length:  502 	Rewards: -148
# [Episode  160] average_length:  594 	Rewards:  -85
# [Episode  180] average_length:  670 	Rewards:  -60
# [Episode  200] average_length:  799 	Rewards:  -44
# [Episode  220] average_length:  903 	Rewards:  -30
# [Episode  240] average_length:  970 	Rewards:  -29
# [Episode  260] average_length: 1000 	Rewards:  -48
# [Episode  280] average_length: 1000 	Rewards:  -56
# [Episode  300] average_length:  982 	Rewards:  -48
# ...

# %% [markdown]
# # Proximal Policy Optimization (PPO)

# %%
kwargs = {
    'lr_actor': 0.002, 
    'lr_critic': 0.002,
    'ppo_update_timestep': 2000,
    'ppo_epsilon': 0.2,
    'ppo_epochs': 10,
}
trainer.train(env_name='LunarLander-v2', algo_name='ppo', solved_reward=200, **kwargs)
# Out:
# Environment: LunarLander-v2 	 State_dim =  8 	 Action_dim =  4
# PPO agent
# learning_rate actor = 0.002, critic = 0.002
# PPO ppo_epsilon 0.2
# PPO update timestep:  2000
# PPO ppo_epochs 10
#
# [Episode   20] average_length:   86 	Rewards: -177
# [Episode   40] average_length:   88 	Rewards: -185
# [Episode   60] average_length:   91 	Rewards: -178
# [Episode   80] average_length:   93 	Rewards: -164
# [Episode  100] average_length:   91 	Rewards: -166
# [Episode  120] average_length:   89 	Rewards: -145
# [Episode  140] average_length:   84 	Rewards: -131
# [Episode  160] average_length:   83 	Rewards: -108
# [Episode  180] average_length:   88 	Rewards: -104
# [Episode  200] average_length:   99 	Rewards: -109
# [Episode  220] average_length:  104 	Rewards: -115
# [Episode  240] average_length:  103 	Rewards: -102
# [Episode  260] average_length:  110 	Rewards:  -92
# [Episode  280] average_length:  117 	Rewards:  -88
# [Episode  300] average_length:  119 	Rewards:  -78
# ...
